# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('50_Startups.csv')
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
data.hist()
plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='R&D Spend',y ='Profit',data= data.head(20) , hue = 'State' )

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
x = data.iloc[:,:-1].values
y = data.iloc[:,4].values
label_e = LabelEncoder()
x[:,3] = label_e.fit_transform(x[:,3])

# %%
onehot = OneHotEncoder(categorical_features=[3])

# %%
x = onehot.fit_transform(x).toarray()
# Out:
# C:\Users\M1\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %%
x.dtype
# Out:
# dtype('float64')

# %%
x = x[:,1:]

# %%
x
# Out:
# array([[0.0000000e+00, 1.0000000e+00, 1.6534920e+05, 1.3689780e+05,
#         4.7178410e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.6259770e+05, 1.5137759e+05,
#         4.4389853e+05],
#        [1.0000000e+00, 0.0000000e+00, 1.5344151e+05, 1.0114555e+05,
#         4.0793454e+05],
#        [0.0000000e+00, 1.0000000e+00, 1.4437241e+05, 1.1867185e+05,
#         3.8319962e+05],
#        [1.0000000e+00, 0.0000000e+00, 1.4210734e+05, 9.1391770e+04,
#         3.6616842e+05],
#        [0.0000000e+00, 1.0000000e+00, 1.3187690e+05, 9.9814710e+04,
#         3.6286136e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.3461546e+05, 1.4719887e+05,
#         1.2771682e+05],
#        [1.0000000e+00, 0.0000000e+00, 1.3029813e+05, 1.4553006e+05,
#         3.2387668e+05],
#        [0.0000000e+00, 1.0000000e+00, 1.2054252e+05, 1.4871895e+05,
#         3.1161329e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.2333488e+05, 1.0867917e+05,
#         3.0498162e+05],
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
multiple_line = LinearRegression()

# %%
multiple_line.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = multiple_line.predict(x_test)

# %%
y_pred
# Out:
# array([192919.57537465])

# %%
display(y_test,y_pred)
# Out:
# array([103282.38, 144259.4 , 146121.95,  77798.83, 191050.39, 105008.31,
#         81229.06,  97483.56, 110352.25, 166187.94])
# array([103015.20159795, 132582.27760817, 132447.73845176,  71976.09851257,
#        178537.48221058, 116161.24230165,  67851.69209675,  98791.73374686,
#        113969.43533013, 167921.06569553])

# %% [markdown]
# # Backward Elimmination Start

# %%
import statsmodels.api as sm

# %%
x = np.append(arr = np.ones([50,1]).astype(int),values=x , axis = 1)
x
# Out:
# array([[1.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.6534920e+05,
#         1.3689780e+05, 4.7178410e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.6259770e+05,
#         1.5137759e+05, 4.4389853e+05],
#        [1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.5344151e+05,
#         1.0114555e+05, 4.0793454e+05],
#        [1.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.4437241e+05,
#         1.1867185e+05, 3.8319962e+05],
#        [1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.4210734e+05,
#         9.1391770e+04, 3.6616842e+05],
#        [1.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.3187690e+05,
#         9.9814710e+04, 3.6286136e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.3461546e+05,
#         1.4719887e+05, 1.2771682e+05],
#        [1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.3029813e+05,
#         1.4553006e+05, 3.2387668e+05],
#        [1.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.2054252e+05,
#         1.4871895e+05, 3.1161329e+05],
# ...

# %%
x_optimal = x[:,[0,1,2,3,4,5]]

# %%
regressor_ols = sm.OLS(endog = y , exog=x_optimal).fit()

# %%
regressor_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     169.9
# Date:                Wed, 20 May 2020   Prob (F-statistic):           1.34e-27
# Time:                        12:25:00   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1063.
# Df Residuals:                      44   BIC:                             1074.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.013e+04   6884.820      7.281      0.000    3.62e+04     6.4e+04
# ...

# %%
x_optimal = x[:,[0,1,3,4,5]]
regressor_ols = sm.OLS(endog = y , exog=x_optimal).fit()
regressor_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     217.2
# Date:                Wed, 20 May 2020   Prob (F-statistic):           8.49e-29
# Time:                        12:26:09   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1061.
# Df Residuals:                      45   BIC:                             1070.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.011e+04   6647.870      7.537      0.000    3.67e+04    6.35e+04
# ...

# %%
x_optimal = x[:,[0,3,4,5]]
regressor_ols = sm.OLS(endog = y , exog=x_optimal).fit()
regressor_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Wed, 20 May 2020   Prob (F-statistic):           4.53e-30
# Time:                        12:26:23   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# ...

# %%
x_optimal = x[:,[0,3,5]]
regressor_ols = sm.OLS(endog = y , exog=x_optimal).fit()
regressor_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     450.8
# Date:                Wed, 20 May 2020   Prob (F-statistic):           2.16e-31
# Time:                        12:33:10   Log-Likelihood:                -525.54
# No. Observations:                  50   AIC:                             1057.
# Df Residuals:                      47   BIC:                             1063.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.698e+04   2689.933     17.464      0.000    4.16e+04    5.24e+04
# ...

# %%
x_optimal = x[:,[0,3,]]
regressor_ols = sm.OLS(endog = y , exog=x_optimal).fit()
regressor_ols.summary()
x_optimal
# Out:
# array([[1.0000000e+00, 1.6534920e+05],
#        [1.0000000e+00, 1.6259770e+05],
#        [1.0000000e+00, 1.5344151e+05],
#        [1.0000000e+00, 1.4437241e+05],
#        [1.0000000e+00, 1.4210734e+05],
#        [1.0000000e+00, 1.3187690e+05],
#        [1.0000000e+00, 1.3461546e+05],
#        [1.0000000e+00, 1.3029813e+05],
#        [1.0000000e+00, 1.2054252e+05],
#        [1.0000000e+00, 1.2333488e+05],
#        [1.0000000e+00, 1.0191308e+05],
#        [1.0000000e+00, 1.0067196e+05],
#        [1.0000000e+00, 9.3863750e+04],
#        [1.0000000e+00, 9.1992390e+04],
#        [1.0000000e+00, 1.1994324e+05],
#        [1.0000000e+00, 1.1452361e+05],
#        [1.0000000e+00, 7.8013110e+04],
#        [1.0000000e+00, 9.4657160e+04],
#        [1.0000000e+00, 9.1749160e+04],
#        [1.0000000e+00, 8.6419700e+04],
#        [1.0000000e+00, 7.6253860e+04],
#        [1.0000000e+00, 7.8389470e+04],
#        [1.0000000e+00, 7.3994560e+04],
#        [1.0000000e+00, 6.7532530e+04],
# ...

# %% [markdown]
# # Automatic Backward Elimination

# %%
#Backward Elimination with p-values only:

import statsmodels.api as sm
def backwardElimination(x, sl):
    numVars = len(x[0])
    for i in range(0, numVars):
        regressor_OLS = sm.OLS(y, x).fit()
        maxVar = max(regressor_OLS.pvalues).astype(float)
        if maxVar > sl:
            for j in range(0, numVars - i):
                if (regressor_OLS.pvalues[j].astype(float) == maxVar):
                    x = np.delete(x, j, 1)
    regressor_OLS.summary()
    return x
    
 
SL = 0.05
X_opt = x[:, [0, 1, 2, 3, 4, 5]]
X_Modeled = backwardElimination(X_opt, SL)
print(X_Modeled)
# Out:
# ...
# [[1.0000000e+00 1.6534920e+05]
#  [1.0000000e+00 1.6259770e+05]
#  [1.0000000e+00 1.5344151e+05]
#  [1.0000000e+00 1.4437241e+05]
#  [1.0000000e+00 1.4210734e+05]
#  [1.0000000e+00 1.3187690e+05]
#  [1.0000000e+00 1.3461546e+05]
#  [1.0000000e+00 1.3029813e+05]
#  [1.0000000e+00 1.2054252e+05]
#  [1.0000000e+00 1.2333488e+05]
#  [1.0000000e+00 1.0191308e+05]
#  [1.0000000e+00 1.0067196e+05]
#  [1.0000000e+00 9.3863750e+04]
#  [1.0000000e+00 9.1992390e+04]
#  [1.0000000e+00 1.1994324e+05]
#  [1.0000000e+00 1.1452361e+05]
#  [1.0000000e+00 7.8013110e+04]
#  [1.0000000e+00 9.4657160e+04]
#  [1.0000000e+00 9.1749160e+04]
#  [1.0000000e+00 8.6419700e+04]
#  [1.0000000e+00 7.6253860e+04]
#  [1.0000000e+00 7.8389470e+04]
#  [1.0000000e+00 7.3994560e+04]
#  [1.0000000e+00 6.7532530e+04]
#  [1.0000000e+00 7.7044010e+04]
#  [1.0000000e+00 6.4664710e+04]
#  [1.0000000e+00 7.5328870e+04]
#  [1.0000000e+00 7.2107600e+04]
#  [1.0000000e+00 6.6051520e+04]
#  [1.0000000e+00 6.5605480e+04]
# ...

# %%
multiple_line1 = LinearRegression()
multiple_line1.fit(x_optimal,data.iloc[:,4])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
multiple_line1.predict([[1,1.6534920e+05]])
# Out:
# array([190289.29389289])

# %%
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
